# %% [markdown]
# #TASK: 2
# # BASIC CHATBOT

# %%
def chatbot():

    print("===================================")
    print(" Welcome to Python Chatbot ")
    print(" Type 'bye' to exit")
    print("===================================")

    while True:

        user = input("\nYou: ").lower()

        if user == "hello":
            print("Bot: Hi! Nice to meet you.")

        elif user == "how are you":
            print("Bot: I am fine, thanks for asking!")

        elif user == "what is your name":
            print("Bot: My name is Python Chatbot.")

        elif user == "who created you":
            print("Bot: I was created using Python programming.")

        elif user == "what can you do":
            print("Bot: I can answer simple predefined questions.")

        elif user == "tell me a joke":
            print("Bot: Why do programmers prefer dark mode? Because light attracts bugs!")

        elif user == "thank you":
            print("Bot: You're welcome!")

        elif user == "bye":
            print("Bot: Goodbye! Have a great day.")
            break

        else:
            print("Bot: Sorry, I don't understand that.")

chatbot()
# Out:
# ...
#  Welcome to Python Chatbot
#  Type 'bye' to exit
# ...
#
# You: hello
# Bot: Hi! Nice to meet you.
#
# You: how are you
# Bot: I am fine, thanks for asking!
#
# You: what is you name
# Bot: Sorry, I don't understand that.
#
# You: what is your name
# Bot: My name is Python Chatbot.
#
# You: who created you
# Bot: I was created using Python programming.
#
# You: bye
# Bot: Goodbye! Have a great day.

# %% [markdown]
# # SUMMARY

# %% [markdown]
# This project is a simple rule-based chatbot built using Python. The chatbot interacts with users through the console and provides predefined responses to common questions and greetings. It uses functions, loops, conditional statements, and string handling to simulate a basic conversation. The chatbot continues running until the user enters "bye", making it an excellent beginner project for learning Python fundamentals and interactive programming.
